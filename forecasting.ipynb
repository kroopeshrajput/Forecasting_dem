# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
register_matplotlib_converters()
from time import time

# %%
catfish_sales = pd.read_csv("C:\Alabs\Datasets\catfish - 1676705276753.csv", parse_dates= [0], index_col= 0 , date_parser= lambda x: datetime.strptime(x, '%Y-%m-%d')).squeeze()
# Out:
# C:\Users\kroop\AppData\Local\Temp\ipykernel_15184\1794862375.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   catfish_sales = pd.read_csv("C:\Alabs\Datasets\catfish - 1676705276753.csv", parse_dates= [0], index_col= 0 , date_parser= lambda x: datetime.strptime(x, '%Y-%m-%d')).squeeze()

# %%
catfish_sales
# Out:
# Date
# 1986-01-01     9034
# 1986-02-01     9596
# 1986-03-01    10558
# 1986-04-01     9002
# 1986-05-01     9239
#               ...
# 2012-08-01    14442
# 2012-09-01    13422
# 2012-10-01    13795
# 2012-11-01    13352
# 2012-12-01    12716
# Name: Total, Length: 324, dtype: int64

# %%
plt.figure(figsize= (25,5))
catfish_sales.plot()
plt.grid()

# %%
plt.figure(figsize=(25, 5))
plt.plot(catfish_sales.diff())
plt.grid()

# %%
from statsmodels.tsa.stattools import adfuller
def adfuller_test(ts):
    adfuller_result = adfuller(ts, autolag=None)
    adfuller_out = pd.Series(adfuller_result[0:4],
    index=["Test Statistic",
            "p-value",
            "Lags Used",
            "Number of Observations Used"])
    print(adfuller_out)

# %%
adfuller_test(catfish_sales)
# Out:
# Test Statistic                  -1.575879
# p-value                          0.495698
# Lags Used                       17.000000
# Number of Observations Used    306.000000
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(catfish_sales.diff().dropna())
plot_pacf(catfish_sales.diff().dropna())
plt.show()
